# %%
import curve as cur
import numpy as np

# %%
x = np.linspace(0,10,1000)

# %%
y = x

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
cur.der(y)
# Out:
# array([ 0.00364149,  0.00850233,  0.00986012,  0.01000393,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
#         0.01000929,  0.01000929,  0.01000929,  0.01000929,  0.01000929,
# ...

# %%
y = np.cos(x)

# %%
dy = cur.der(y)

# %%
plt.plot(x, dy)

# %%
plt.show()

# %%
y = x

# %%
cur.der(f = y, x=x, iwidth = 0.65)
# Out:
# array([ 0.47027564,  0.96619089,  0.99193365,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
#         0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,  0.9920368 ,
# ...

# %%
plt.

# %%
x
# Out:
# array([  0.        ,   0.01001001,   0.02002002,   0.03003003,
#          0.04004004,   0.05005005,   0.06006006,   0.07007007,
#          0.08008008,   0.09009009,   0.1001001 ,   0.11011011,
#          0.12012012,   0.13013013,   0.14014014,   0.15015015,
#          0.16016016,   0.17017017,   0.18018018,   0.19019019,
#          0.2002002 ,   0.21021021,   0.22022022,   0.23023023,
#          0.24024024,   0.25025025,   0.26026026,   0.27027027,
#          0.28028028,   0.29029029,   0.3003003 ,   0.31031031,
#          0.32032032,   0.33033033,   0.34034034,   0.35035035,
#          0.36036036,   0.37037037,   0.38038038,   0.39039039,
#          0.4004004 ,   0.41041041,   0.42042042,   0.43043043,
#          0.44044044,   0.45045045,   0.46046046,   0.47047047,
#          0.48048048,   0.49049049,   0.5005005 ,   0.51051051,
#          0.52052052,   0.53053053,   0.54054054,   0.55055055,
#          0.56056056,   0.57057057,   0.58058058,   0.59059059,
# ...

# %%
y
# Out:
# array([  0.        ,   0.01001001,   0.02002002,   0.03003003,
#          0.04004004,   0.05005005,   0.06006006,   0.07007007,
#          0.08008008,   0.09009009,   0.1001001 ,   0.11011011,
#          0.12012012,   0.13013013,   0.14014014,   0.15015015,
#          0.16016016,   0.17017017,   0.18018018,   0.19019019,
#          0.2002002 ,   0.21021021,   0.22022022,   0.23023023,
#          0.24024024,   0.25025025,   0.26026026,   0.27027027,
#          0.28028028,   0.29029029,   0.3003003 ,   0.31031031,
#          0.32032032,   0.33033033,   0.34034034,   0.35035035,
#          0.36036036,   0.37037037,   0.38038038,   0.39039039,
#          0.4004004 ,   0.41041041,   0.42042042,   0.43043043,
#          0.44044044,   0.45045045,   0.46046046,   0.47047047,
#          0.48048048,   0.49049049,   0.5005005 ,   0.51051051,
#          0.52052052,   0.53053053,   0.54054054,   0.55055055,
#          0.56056056,   0.57057057,   0.58058058,   0.59059059,
# ...

# %%
dy = np.diff(y)

# %%
len(y) - len(dy)
# Out:
# 1

# %%
test = np.ones(3)

# %%
dt = np.diff(test)

# %%
len(test) - len(dt)
# Out:
# 1

# %%
len(y)
# Out:
# 1000

# %%
dy = np.diff(y)

# %%
len(dy)
# Out:
# 999

# %%
beg, end = 1//2, 2//2

# %%
dy[0]* beg
# Out:
# 0.0

# %%
dy[-1]
# Out:
# 0.010010010010010006

# %%
dy = np.diff(y)

# %%
dy[-1]
# Out:
# 0.010010010010010006

# %%
x = np.linspace(0,2*np.pi,1000)

# %%
y = np.sin(x)

# %%
dy = cur.der(y, x= x, order = 2, iwidth = 0.65)

# %%
plt.plot(x, dy)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
for width in np.arange(0.5, 10, 0.5):
    z = cur.der(x ** 2, x=x , iwidth = width)
    plt.plot(x, z)
    plt.show()

# %%
y
# Out:
# array([  0.        ,   0.01001001,   0.02002002,   0.03003003,
#          0.04004004,   0.05005005,   0.06006006,   0.07007007,
#          0.08008008,   0.09009009,   0.1001001 ,   0.11011011,
#          0.12012012,   0.13013013,   0.14014014,   0.15015015,
#          0.16016016,   0.17017017,   0.18018018,   0.19019019,
#          0.2002002 ,   0.21021021,   0.22022022,   0.23023023,
#          0.24024024,   0.25025025,   0.26026026,   0.27027027,
#          0.28028028,   0.29029029,   0.3003003 ,   0.31031031,
#          0.32032032,   0.33033033,   0.34034034,   0.35035035,
#          0.36036036,   0.37037037,   0.38038038,   0.39039039,
#          0.4004004 ,   0.41041041,   0.42042042,   0.43043043,
#          0.44044044,   0.45045045,   0.46046046,   0.47047047,
#          0.48048048,   0.49049049,   0.5005005 ,   0.51051051,
#          0.52052052,   0.53053053,   0.54054054,   0.55055055,
#          0.56056056,   0.57057057,   0.58058058,   0.59059059,
# ...

# %%
z
# Out:
# array([ 0.04194592,  0.125375  ,  0.20743105,  0.28724875,  0.36403493,
#         0.43709197,  0.50583613,  0.56981024,  0.62869009,  0.6822849 ,
#         0.73053206,  0.77348695,  0.81130894,  0.84424452,  0.87260891,
#         0.89676719,  0.91711602,  0.93406677,  0.94803072,  0.95940667,
#         0.96857132,  0.97587221,  0.98162322,  0.98610228,  0.98955099,
#         0.99217574,  0.9941499 ,  0.99561679,  0.99669304,  0.9974722 ,
#         0.99802814,  0.99841842,  0.99868723,  0.99886804,  0.99898586,
#         0.99905912,  0.99910125,  0.99912186,  0.99912779,  0.99912779,
#         0.99912779,  0.99912779,  0.99912779,  0.99912779,  0.99912779,
#         0.99912779,  0.99912779,  0.99912779,  0.99912779,  0.99912779,
#         0.99912779,  0.99912779,  0.99912779,  0.99912779,  0.99912779,
#         0.99912779,  0.99912779,  0.99912779,  0.99912779,  0.99912779,
#         0.99912779,  0.99912779,  0.99912779,  0.99912779,  0.99912779,
# ...

# %%
x = np.array(np.arange(0, 10, 0.005))

# %%
x = np.linspace(0,10,1000)

# %%
x
# Out:
# array([  0.00000000e+00,   5.00000000e-03,   1.00000000e-02, ...,
#          9.98500000e+00,   9.99000000e+00,   9.99500000e+00])

# %%
dy = np.linspace(0, 2*np.pi, 2001)

# %%
y = np.sin(dy)

# %%
import curve

# %%
plt.plot(curve.der(y, x = dy, iwidth= 0.5, order = 1))
plt.ylim([-1,1])
plt.show()

# %%
import correlation as corr

# %%
corr.crosscorr?

# %%
a = np.array([1, 3, 5])
b = np.array([2, 4, 6])

# %%
c = np.array([11, 44/3.0, 13])

# %%
corr.crosscorr(a,b, cumulant= False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-6cbc628469bc> in <module>()
# ----> 1 corr.crosscorr(a,b, cumulant= False)
#
# /Users/zhejun/Document/Research Code/track/correlation.py in crosscorr(f, g, side, cumulant, norm, mode, verbose, reverse, ret_dx)
#     514         assert np.allclose(n, overlap), msg.format(n, overlap)
#     515         assert n[m] == l, "overlap normalizer not l at m"
# --> 516     c /= n
#     517     c = c.T
#     518     if verbose:
#
# TypeError: ufunc 'true_divide' output (typecode 'd') could not be coerced to provided output parameter (typecode 'l') according to the casting rule ''same_kind''

# %%
a = a - np.nanmean(a)

# %%
a
# Out:
# array([-2.,  0.,  2.])

# %%
b = b - np.nanmean(b)

# %%
b
# Out:
# array([-2.,  0.,  2.])

# %%
reload()
